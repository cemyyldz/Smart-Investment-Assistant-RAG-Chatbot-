# %%
# !pip install -r requirements.txt
# Gerekli tüm kütüphanelerin tek seferde kurulması
# NOT: Bu komutlar, projenin requirements.txt dosyasında listelenen bağımlılıkları kapsar.
# !pip install -q python-dotenv langchain-google-genai langchain-community langchain-core langchain_text_splitters streamlit
# Out:
# Requirement already satisfied: python-dotenv in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: langchain in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: langchain-core in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: langchain-community in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 7)) (0.4)
# Requirement already satisfied: langchain_text_splitters in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: langchain-google-genai in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: chromadb in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 14)) (1.2.0)
# Requirement already satisfied: streamlit in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 17)) (1.50.0)
# Requirement already satisfied: pydantic in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 20)) (2.12.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain->-r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core->-r requirements.txt (line 6)) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core->-r requirements.txt (line 6)) (0.4.37)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core->-r requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core->-r requirements.txt (line 6)) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core->-r requirements.txt (line 6)) (4.15.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community->-r requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community->-r requirements.txt (line 7)) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community->-r requirements.txt (line 7)) (2.32.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community->-r requirements.txt (line 7)) (3.13.1)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community->-r requirements.txt (line 7)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community->-r requirements.txt (line 7)) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community->-r requirements.txt (line 7)) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community->-r requirements.txt (line 7)) (2.1.3)
# Requirement already satisfied: google-ai-generativelanguage<1.0.0,>=0.7.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-google-genai->-r requirements.txt (line 11)) (0.8.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-google-genai->-r requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 14)) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (1.23.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (1.75.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (0.19.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (3.11.3)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb->-r requirements.txt (line 14)) (4.23.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from streamlit->-r requirements.txt (line 17)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from streamlit->-r requirements.txt (line 17)) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from streamlit->-r requirements.txt (line 17)) (6.2.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from streamlit->-r requirements.txt (line 17)) (8.3.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from streamlit->-r requirements.txt (line 17)) (2.3.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from streamlit->-r requirements.txt (line 17)) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from streamlit->-r requirements.txt (line 17)) (6.33.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from streamlit->-r requirements.txt (line 17)) (21.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from streamlit->-r requirements.txt (line 17)) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from streamlit->-r requirements.txt (line 17)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from streamlit->-r requirements.txt (line 17)) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from streamlit->-r requirements.txt (line 17)) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from streamlit->-r requirements.txt (line 17)) (6.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->-r requirements.txt (line 20)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->-r requirements.txt (line 20)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->-r requirements.txt (line 20)) (0.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 7)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 7)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 7)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 7)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 7)) (1.22.0)
# Requirement already satisfied: jinja2 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 17)) (3.1.6)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 17)) (2.9.0)
# Requirement already satisfied: pyproject_hooks in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 14)) (1.2.0)
# Requirement already satisfied: colorama in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r requirements.txt (line 7)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r requirements.txt (line 7)) (0.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 17)) (4.0.12)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai->-r requirements.txt (line 11)) (2.26.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai->-r requirements.txt (line 11)) (2.41.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai->-r requirements.txt (line 11)) (1.26.1)
# Requirement already satisfied: anyio in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 14)) (4.9.0)
# Requirement already satisfied: certifi in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 14)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 14)) (1.0.8)
# Requirement already satisfied: idna in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 14)) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->-r requirements.txt (line 14)) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->-r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 14)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 14)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 14)) (0.24.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 14)) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 14)) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 14)) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 14)) (0.10)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph<1.1.0,>=1.0.0->langchain->-r requirements.txt (line 5)) (2.1.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph<1.1.0,>=1.0.0->langchain->-r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph<1.1.0,>=1.0.0->langchain->-r requirements.txt (line 5)) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph<1.1.0,>=1.0.0->langchain->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r requirements.txt (line 6)) (0.25.0)
# Requirement already satisfied: coloredlogs in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 14)) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 14)) (25.2.10)
# Requirement already satisfied: sympy in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 14)) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 14)) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 14)) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 14)) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 14)) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-sdk>=1.2.0->chromadb->-r requirements.txt (line 14)) (0.59b0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 17)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 17)) (2025.2)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from posthog<6.0.0,>=2.4.0->chromadb->-r requirements.txt (line 14)) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from posthog<6.0.0,>=2.4.0->chromadb->-r requirements.txt (line 14)) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.32.5->langchain-community->-r requirements.txt (line 7)) (3.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich>=10.11.0->chromadb->-r requirements.txt (line 14)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich>=10.11.0->chromadb->-r requirements.txt (line 14)) (2.19.1)
# Requirement already satisfied: greenlet>=1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community->-r requirements.txt (line 7)) (3.2.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tokenizers>=0.13.2->chromadb->-r requirements.txt (line 14)) (0.35.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typer>=0.9.0->chromadb->-r requirements.txt (line 14)) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 14)) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 14)) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 14)) (15.0.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 17)) (5.0.2)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai->-r requirements.txt (line 11)) (1.75.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai->-r requirements.txt (line 11)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai->-r requirements.txt (line 11)) (4.9.1)
# Requirement already satisfied: filelock in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb->-r requirements.txt (line 14)) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb->-r requirements.txt (line 14)) (2025.9.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 14)) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 17)) (3.0.2)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.0->langchain->-r requirements.txt (line 5)) (1.11.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->-r requirements.txt (line 14)) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio->httpx>=0.27.0->chromadb->-r requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 14)) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 14)) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 14)) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\cem yıldız\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai->-r requirements.txt (line 11)) (0.6.1)
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: C:\Users\Cem Yıldız\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# .env dosyasındaki ortam değişkenlerini yükle
# Güvenlik nedeniyle API Anahtarı doğrudan koda yazılmaz.
import os
from dotenv import load_dotenv

load_dotenv()

try:
    api_key = os.getenv("GEMINI_API_KEY")
    
    if not api_key:
        raise ValueError("Lütfen .env dosyasında 'GEMINI_API_KEY' değerini ayarlayın.")
        
    print("API Anahtarı başarıyla .env dosyasından yüklendi.")
    
except ValueError as e:
    print(f"Hata: {e}")
# API Anahtarının yüklendiğini kontrol et
# Out:
# API Anahtarı başarıyla .env dosyasından yüklendi.

# %%
# Gerekli LangChain bileşenlerini içe aktar
from langchain_community.document_loaders import TextLoader

from langchain_text_splitters import RecursiveCharacterTextSplitter 

# 1. Veri setini yükle
# Teknik Anlatım: TextLoader, dosyayı yükler. Encoding='utf-8' parametresi 
# özel Türkçe karakterler nedeniyle ortaya çıkan 'UnicodeDecodeError' hatasını engeller.
loader = TextLoader("yatirim_verileri.txt", encoding="utf-8")
documents = loader.load()

# 2. Metni parçalara ayırma (Text Splitting)
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, 
    chunk_overlap=100,
    separators=["\n\n", "\n", " ", ""]
)
# chunk_size=1000: Her parçanın maksimum boyutu.
# chunk_overlap=100: Bağlam kaybını önlemek için parçalar arası örtüşme.

texts = text_splitter.split_documents(documents)

print(f"Yüklenen belge sayısı: {len(documents)}")
print(f"Toplam {len(documents)} belge, {len(texts)} parçaya (chunks) ayrıldı.")
print("\nÖrnek bir parçanın başlangıcı:")
print(texts[0].page_content[:200] + "...")
# Out:
# Yüklenen belge sayısı: 1
# Toplam 1 belge, 11 parçaya (chunks) ayrıldı.
#
# Örnek bir parçanın başlangıcı:
# === ALTIN YATIRIMI ===
# Altın, tarih boyunca en güvenilir yatırım araçlarından biri olarak kabul edilmiştir. İnsanlık tarihi boyunca para birimi, değer ölçüsü ve zenginlik göstergesi olarak kullanılmış...

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import Chroma
import os

# 1. API Anahtarını Ortam Değişkenlerinden Çekme
# Bu, daha önceki hücrede (Hücre 1) load_dotenv() ile yüklenmiştir.
api_key = os.getenv("GEMINI_API_KEY")

# 2. Embedding Modelini Tanımlama
# Şimdi anahtarı açıkça 'google_api_key' parametresi ile geçiriyoruz.
embedding_model = GoogleGenerativeAIEmbeddings(
    model="text-embedding-004", 
    google_api_key=api_key # Anahtarı buraya ekliyoruz
) 

# 3. ChromaDB Vektör Veritabanını Oluşturma
print("\nVektör veritabanı oluşturuluyor ve 11 parça vektörleştiriliyor...")

vectorstore = Chroma.from_documents(
    documents=texts,  
    embedding=embedding_model, 
    persist_directory="./chroma_db_yatirim" 
)

# Retriever (Bilgi Çekici) oluşturma
retriever = vectorstore.as_retriever(search_kwargs={"k": 3})
# Retriever, sorgu geldiğinde vektör veritabanından en alakalı parçaları çekecektir.
# search_kwargs={"k": 3}: Her sorgu için en alakalı 3 (top-k) parçayı çeker.

print("Vektör veritabanı başarıyla oluşturuldu ve diske kaydedildi.")
print(f"Retriever (Bilgi Çekici) hazırlandı. Her sorgu için en alakalı {retriever.search_kwargs['k']} parça çekilecek.")
# Out:
# Vektör veritabanı oluşturuluyor ve 11 parça vektörleştiriliyor...
# Vektör veritabanı başarıyla oluşturuldu ve diske kaydedildi.
# Retriever (Bilgi Çekici) hazırlandı. Her sorgu için en alakalı 3 parça çekilecek.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser
import os

# 1. LLM (Gemini) Modelini Tanımlama
# Teknik Anlatım: gemini-2.5-flash modeli hız ve performans dengesi için seçilmiştir.
# temperature=0.1: Düşük sıcaklık, modelin daha az yaratıcı, daha olgusal (yatırım için kritik) yanıtlar vermesini sağlar.
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    google_api_key=os.getenv("GEMINI_API_KEY"),
    temperature=0.1
)

# 2. Prompt (İstem) Şablonunu Hazırlama
# Prompt, modele kesin talimatlar verir: SADECE bağlamı kullan ve bilmediğinde reddet.
prompt = ChatPromptTemplate.from_template("""
Sen, Akıllı Yatırım Asistanısın. Görevin, SADECE sağlanan bağlam bilgisine (Context) dayanarak 
kullanıcının yatırım ve finansal konularla ilgili sorularını yanıtlamaktır. 
Eğer bağlamda soruya dair net bir bilgi yoksa, "Üzgünüm, bu konuda elimdeki veri setinde yeterli bilgi bulunmamaktadır." 
diye yanıt ver. Fikir yürütme veya genel bilgi verme.

Bağlam (Context):
{context}

Soru: {question}
""")

# 3. RAG Zincirini Runnable (Çalıştırılabilir) Olarak Kurma (Hata vermez!)
# Bu zincir: Giriş -> Bağlamı Çek (Retriever) -> Prompt'u Hazırla -> LLM'e Gönder -> Yanıtı Çöz (Output Parser)
# RunnableLambda: Retriever'dan gelen liste formatındaki belgeleri (docs), LLM'in isteyeceği tek bir metin dizesine dönüştürür.

def format_docs(docs):
    # Retriever'dan gelen belge listesini (texts), tek bir dizeye dönüştürür
    return "\n\n".join(doc.page_content for doc in docs)

rag_chain = (
    # 1. RunnablePassthrough: Girişi alır ve bir sonraki adıma aktarır (question olarak)
    # 2. RunnableLambda: Retriever'ı çalıştırır ve çıktısını format_docs ile işler (context olarak)
    {"context": retriever | RunnableLambda(format_docs), "question": RunnablePassthrough()}
    | prompt  # 3. Prompt: context ve question ile doldurulur
    | llm     # 4. LLM: Yanıtı oluşturur
    | StrOutputParser() # 5. Output Parser: Çıktıyı düz metne çevirir
)

print("RAG Zinciri (Runnable Pipeline) başarıyla oluşturuldu. Artık sorgu yapabiliriz.")

# 4. İlk Test Sorgusu
print("-" * 50)
soru = "Portföy çeşitlendirmesi neden önemlidir ve hangi varlıklar önerilir?"
print(f"Kullanıcı Sorusu: {soru}")

# Zinciri çalıştırma
# Runnable zinciri, doğrudan string veya dict alabilir. 'invoke' ile çalıştırıyoruz.
response = rag_chain.invoke(soru)

print("\nAsistanın Yanıtı:")
print(response)
# Out:
# RAG Zinciri (Runnable Pipeline) başarıyla oluşturuldu. Artık sorgu yapabiliriz.
# --------------------------------------------------
# Kullanıcı Sorusu: Portföy çeşitlendirmesi neden önemlidir ve hangi varlıklar önerilir?
#
# Asistanın Yanıtı:
# Portföy çeşitlendirmesi, farklı varlık türlerine yatırım yaparak toplam riski azaltmak anlamına gelir. Bu yöntem, modern portföy teorisinin temelini oluşturur. Örneğin, portföyde hem hisse hem tahvil hem de altın bulunması, tek bir varlığın kötü performans göstermesi durumunda toplam zararı sınırlar.
#
# Önerilen varlıklar yatırımcının risk profiline göre değişir:
# *   **Düşük riskli yatırımcılar için:** Mevduat, tahvil, fon ağırlıklı portföy.
# *   **Orta riskli yatırımcılar için:** Hisse ve fon karışımı.
# *   **Yüksek riskli yatırımcılar için:** Hisse, kripto veya türev ürün ağırlıklı portföy.
